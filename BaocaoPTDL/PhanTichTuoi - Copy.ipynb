# %%
import pandas as pd
import matplotlib.pyplot as plt

# Đọc dữ liệu từ tệp csv
df = pd.read_csv('TyleTNtheoTuoidaxuly.csv')

# Hiển thị các dòng đầu tiên của DataFrame để kiểm tra dữ liệu
print(df.head())
import matplotlib.pyplot as plt

# Đọc dữ liệu từ tệp CSV
df = pd.read_csv('TyleTNtheoTuoidaxuly.csv')

# Kiểm tra các dòng đầu tiên của DataFrame
print(df.head())

# Giả sử bạn muốn vẽ biểu đồ cột từ cột 'Age' và 'Value'
# (Đảm bảo các cột này tồn tại trong DataFrame)

# Vẽ biểu đồ cột
plt.figure(figsize=(10, 6))  # Thiết lập kích thước cho biểu đồ

# Sử dụng `plt.bar()` để vẽ biểu đồ cột
plt.bar(df['Age group'], df['Value'], color='blue')

# Thêm tiêu đề và nhãn cho các trục
plt.title('Biểu đồ cột theo độ tuổi')
plt.xlabel('Độ tuổi')
plt.ylabel('Giá trị')

# Hiển thị biểu đồ
plt.show()
# Out:
#     Country Age group    Value
# 0  Viet Nam     15-19   94.496
# 1  Viet Nam     20-24  244.343
# 2  Viet Nam     25-29  161.619
# 3  Viet Nam     30-34  110.208
# 4  Viet Nam     35-39   72.444
#     Country Age group    Value
# 0  Viet Nam     15-19   94.496
# 1  Viet Nam     20-24  244.343
# 2  Viet Nam     25-29  161.619
# 3  Viet Nam     30-34  110.208
# 4  Viet Nam     35-39   72.444
