# %%
import pandas as pd
import matplotlib.pyplot as plt

# Đọc dữ liệu từ tệp csv
df = pd.read_csv('TongGDP.csv')

# Hiển thị các dòng đầu tiên của DataFrame để kiểm tra dữ liệu
print(df.head())
# Đọc dữ liệu từ tệp CSV
df = pd.read_csv('TongGDP.csv')

# Kiểm tra các dòng đầu tiên của DataFrame
print(df.head())

# Giả sử bạn muốn vẽ biểu đồ cột từ cột 'Age' và 'Value'
# (Đảm bảo các cột này tồn tại trong DataFrame)

# Vẽ biểu đồ cột
plt.figure(figsize=(10, 6))  # Thiết lập kích thước cho biểu đồ

# Sử dụng `plt.bar()` để vẽ biểu đồ cột
plt.bar(df['Time'], df['Value'], color='blue')

# Thêm tiêu đề và nhãn cho các trục
plt.title('Biểu đồ cột theo tổng GDP qua các năm')
plt.xlabel('Năm')
plt.ylabel('Giá trị')

# Hiển thị biểu đồ
plt.show()
# Vẽ biểu đồ đường
plt.figure(figsize=(10, 6))  # Thiết lập kích thước cho biểu đồ

# Sử dụng plt.plot() để vẽ biểu đồ đường
plt.plot(df['Time'], df['Value'], marker='o', color='blue', linestyle='-')

# Thêm tiêu đề và nhãn cho các trục
plt.title('Biểu đồ đường theo tổng GDP qua các năm')
plt.xlabel('Năm')
plt.ylabel('Giá trị')

# Hiển thị biểu đồ
plt.show()
# Out:
#    Time  Value
# 0  2018  310.1
# 1  2019  334.3
# 2  2020  346.6
# 3  2021  366.1
# 4  2022  408.8
#    Time  Value
# 0  2018  310.1
# 1  2019  334.3
# 2  2020  346.6
# 3  2021  366.1
# 4  2022  408.8
